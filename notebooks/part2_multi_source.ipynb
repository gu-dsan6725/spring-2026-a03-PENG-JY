# %% [markdown]
# # Part 2: Multi-Source RAG with Query Routing
#
# Intelligently routes queries to CSV (sales data) or text (product pages) based on question type.
#
# **Architecture:** User Query → Query Router → CSV / Text / Both → LLM Answer
#
# All pipeline logic lives in `src/part2_pipeline.py`.

# %% [markdown]
# ## Step 1: Setup

# %%
import sys
import os

# Make sure the project root is on the path so src/ can be imported
sys.path.insert(0, os.path.abspath(".."))

from src.part2_pipeline import answer_question, classify_query
from src.config import CSV_PATH, TEXT_DIR, GROQ_MODEL

print("Imports OK")
print(f"  CSV  : {CSV_PATH}")
print(f"  Text : {TEXT_DIR}")
print(f"  Model: {GROQ_MODEL}")
# Out:
# Imports OK
#   CSV  : ./data/structured/daily_sales.csv
#   Text : ./data/unstructured/
#   Model: llama-3.3-70b-versatile

# %% [markdown]
# ## Step 2: Explore the Data

# %%
import glob
import pandas as pd

# Preview CSV structure
df = pd.read_csv(CSV_PATH)
print("Shape:", df.shape)
print("Columns:", list(df.columns))
print("Date range:", df["date"].min(), "to", df["date"].max())
print("Categories:", sorted(df["category"].unique()))
print("Regions:", sorted(df["region"].unique()))
df.head(3)
# Out:
# Shape: (1000, 8)
# Columns: ['date', 'product_id', 'product_name', 'category', 'units_sold', 'unit_price', 'total_revenue', 'region']
# Date range: 2024-10-03 to 2024-12-31
# Categories: ['Beauty & Personal Care', 'Books', 'Clothing', 'Electronics', 'Food & Grocery', 'Home & Kitchen', 'Office Supplies', 'Pet Supplies', 'Sports & Outdoors', 'Toys & Games']
# Regions: ['Central', 'East', 'North', 'South', 'West']
#          date product_id              product_name     category  units_sold  \
# 0  2024-10-03    BOOK003  Mystery Novel Collection        Books          42
# 1  2024-10-03    ELEC002        USB-C Fast Charger  Electronics          57
# 2  2024-10-03    BOOK001  Python Programming Guide        Books          39
#
#    unit_price  total_revenue   region
# 0       24.99        1049.58  Central
# 1       24.99        1424.43  Central
# 2       39.65        1546.35     West

# %%
# List available product text files
txt_files = sorted(glob.glob(os.path.join(TEXT_DIR, "*.txt")))
print(str(len(txt_files)) + " product page files found:")
for f in txt_files:
    print("  " + os.path.basename(f))

# Preview one file
with open(txt_files[0]) as f:
    print("\nPreview of " + os.path.basename(txt_files[0]))
    print("=" * 50)
    print(f.read()[:800])
# Out:
# 10 product page files found:
#   BEAU001_product_page.txt
#   BOOK001_product_page.txt
#   CLTH001_product_page.txt
#   ELEC001_product_page.txt
#   FOOD001_product_page.txt
#   HOME003_product_page.txt
#   OFFC001_product_page.txt
#   PETS001_product_page.txt
#   SPRT001_product_page.txt
#   TOYS001_product_page.txt
#
# Preview of BEAU001_product_page.txt
# ==================================================
# ========================================
# VITAMIN C SERUM - PRODUCT PAGE
# ========================================
#
# Product: Vitamin C Serum
# Brand: GlowLab Skincare
# Price: $28.99
# SKU: BEAU001
# Category: Beauty & Personal Care
#
# PRODUCT DESCRIPTION:
# Reveal brighter, more youthful skin with GlowLab's Vitamin C Serum. This powerful
# antioxidant formula combines 20% Vitamin C (L-Ascorbic Acid) with Vitamin E and
# Hyaluronic Acid to reduce dark spots, fine lines, and sun damage while hydrating
# and protecting your skin.
#
# Key Ingredients:
# - 20% L-Ascorbic Acid (Vitamin C) - brightens and evens skin tone
# - Vitamin E - enhances antioxidant protection
# - Hyaluronic Acid - deep hydration and plumping
# - Ferulic Acid - stabilizes vitamins C and E, boosts effectiveness
# - Aloe Vera - soothes and calms skin
#
# Ben

# %% [markdown]
# ## Step 3: Verify the Router
#
# Confirm the router correctly classifies all 6 test questions before running them.

# %%
all_questions = [
    "What was the total revenue for Electronics category in December 2024?",
    "Which region had the highest sales volume?",
    "What are the key features of the Wireless Bluetooth Headphones?",
    "What do customers say about the Air Fryer's ease of cleaning?",
    "Which product has the best customer reviews and how well is it selling?",
    "I want a product for fitness that is highly rated and sells well in the West region. What do you recommend?",
]

print("Router classification preview")
print("=" * 60)
for i, q in enumerate(all_questions, 1):
    result = classify_query(q)
    print(f"Q{i} [{result['route'].upper():4s}] {q[:55]}")
    print(f"     → {result['reasoning']}")
    print()
# Out:
# Router classification preview
# ============================================================
# Q1 [CSV ] What was the total revenue for Electronics category in
#      → The question is about total revenue, which is a numerical value that can be found in the structured CSV data.
#
# Q2 [CSV ] Which region had the highest sales volume?
#      → The question is about sales volume, which is a numerical metric that can be found in the structured CSV data.
#
# Q3 [TEXT] What are the key features of the Wireless Bluetooth Hea
#      → The question is about product features, which is best answered by the unstructured text data in the product page files.
#
# Q4 [TEXT] What do customers say about the Air Fryer's ease of cle
#      → The question is about customer reviews, which is purely about unstructured text data.
#
# Q5 [BOTH] Which product has the best customer reviews and how wel
#      → The question requires combining sales performance from the CSV data with customer review information from the text data to determine the product with the best reviews and its sales performance.
#
# Q6 [BOTH] I want a product for fitness that is highly rated and s
#      → The question requires combining sales performance in the West region with product quality and customer reviews, which involves both numerical data and text analysis.

# %% [markdown]
# ## Step 4: Questions 1–2 (CSV Only)
#
# Analytical questions answered entirely from the sales CSV.

# %%
csv_questions = [
    "What was the total revenue for Electronics category in December 2024?",
    "Which region had the highest sales volume?",
]

RESULTS_FILE = "./part2_results.txt"

# Start results file fresh
with open(RESULTS_FILE, "w") as f:
    f.write("Part 2: Multi-Source RAG Results\n" + "=" * 60 + "\n\n")

for i, q in enumerate(csv_questions, 1):
    answer = answer_question(q)
    print("\n" + "="*60 + "\n[ANSWER]\n" + "="*60)
    print(answer)
    with open(RESULTS_FILE, "a") as f:
        f.write("Q" + str(i) + ": " + q + "\n" + "=" * 60 + "\n" + answer + "\n\n")
    print("[Saved Q" + str(i) + "]")
# Out:
# ============================================================
# Question: What was the total revenue for Electronics category in December 2024?
# ============================================================
#
# [Router] Route     : CSV
# [Router] Reasoning : The question is about total revenue, which is a numerical value related to sales, so it should be routed to the csv data source.
# [Router] CSV hint  : Filter by 'category' = 'Electronics' and 'date' = 'December 2024', then aggregate 'total_revenue' column
# [Router] Text hint :
#
# [Retrieving] → CSV source...
#
# [Generating answer...]
#
# ============================================================
# [ANSWER]
# ============================================================
# The total revenue for the Electronics category in December 2024 was $142,864.31. This information can be found in the "Revenue by Category in December" section of the provided context.
# [Saved Q1]
#
# ============================================================
# Question: Which region had the highest sales volume?
# ============================================================
#
# [Router] Route     : CSV
# [Router] Reasoning : The question is about sales volume, which is a numerical metric that can be found in the structured CSV data.
# [Router] CSV hint  : Use the 'units_sold' column and apply a groupby operation on the 'region' column to find the region with the highest sales volume.
# [Router] Text hint :
#
# [Retrieving] → CSV source...
#
# [Generating answer...]
#
# ============================================================
# [ANSWER]
# ============================================================
# Based on the sales data, the Central region had the highest sales volume, with a total of 6779 units sold. This is the highest among all regions, followed by the East region with 5678 units sold, the North region with 5610 units sold, the West region with 5423 units sold, and the South region with 5314 units sold.
#
# To put this into perspective, the Central region accounted for approximately 23.5% of the total units sold (6779 out of 28804 total units sold across all regions).
#
# Source: Total Units Sold by Region (CSV data)
# [Saved Q2]

# %% [markdown]
# ## Step 5: Questions 3–4 (Text Only)
#
# Product detail and review questions answered from the unstructured text files.

# %%
# Q3-Q4
text_questions = [
    "What are the key features of the Wireless Bluetooth Headphones?",
    "What do customers say about the Air Fryer's ease of cleaning?",
]

for i, q in enumerate(text_questions, 3):
    answer = answer_question(q)
    print("\n" + "="*60 + "\n[ANSWER]\n" + "="*60)
    print(answer)
    with open(RESULTS_FILE, "a") as f:
        f.write("Q" + str(i) + ": " + q + "\n" + "=" * 60 + "\n" + answer + "\n\n")
    print("[Saved Q" + str(i) + "]")
# Out:
# ============================================================
# Question: What are the key features of the Wireless Bluetooth Headphones?
# ============================================================
#
# [Router] Route     : TEXT
# [Router] Reasoning : The question is about product features, which is best answered by the unstructured text data in the product page files.
# [Router] CSV hint  :
# [Router] Text hint : Search the 'ELEC001_product_page.txt' file for keywords like 'Wireless Bluetooth Headphones' and 'features'.
# [Retrieving] → Text source...
#
# [Generating answer...]
#
# ============================================================
# [ANSWER]
# ============================================================
# The key features of the Wireless Bluetooth Headphones (SKU: ELEC001) are:
#
# 1. Active Noise Cancellation (ANC)
# 2. Transparency mode
# 3. 40-hour battery life
#
# As one customer, Emily W., mentioned in her review, the "noise cancellation is amazing, especially for announcements on the train." However, another customer, David R., noted that the "noise cancellation is decent but not as good as the premium brands."
#
# These features are highlighted in the product description and supported by customer reviews, with an average rating of 4.4/5 from 2,847 reviews.
# [Saved Q3]
#
# ============================================================
# Question: What do customers say about the Air Fryer's ease of cleaning?
# ============================================================
#
# [Router] Route     : TEXT
# [Router] Reasoning : The question is about customer reviews, which is purely about unstructured text data.
# [Router] CSV hint  :
# [Router] Text hint : Search 'ELEC001_product_page.txt' for keywords like 'Air Fryer' and 'ease of cleaning'
# [Retrieving] → Text source...
#
# [Generating answer...]
#
# ============================================================
# [ANSWER]
# ============================================================
# According to customer reviews, the Air Fryer 5.5L by KitchenPro Elite is easy to clean. Review 2 by Lisa G. (Verified Purchase) mentions that "cleanup is a breeze." Additionally, Review 5 by Maria S. (Verified Purchase) does not mention any issues with cleaning, but rather compliments the air fryer's performance. The product description also highlights that the "removable basket and pan" are "dishwasher-safe", which suggests that cleaning is convenient. Overall, customers seem to be satisfied with the ease of cleaning the Air Fryer 5.5L.
# [Saved Q4]

# %% [markdown]
# ## Step 6: Questions 5–6 (Both Sources)
#
# Complex questions combining sales data with product review insights.

# %%
# Q5-Q6
both_questions = [
    "Which product has the best customer reviews and how well is it selling?",
    "I want a product for fitness that is highly rated and sells well in the West region. What do you recommend?",
]

for i, q in enumerate(both_questions, 5):
    answer = answer_question(q)
    print("\n" + "="*60 + "\n[ANSWER]\n" + "="*60)
    print(answer)
    with open(RESULTS_FILE, "a") as f:
        f.write("Q" + str(i) + ": " + q + "\n" + "=" * 60 + "\n" + answer + "\n\n")
    print("[Saved Q" + str(i) + "]")

print("\n✅ All results saved to part2_results.txt")
# Out:
# ============================================================
# Question: Which product has the best customer reviews and how well is it selling?
# ============================================================
#
# [Router] Route     : BOTH
# [Router] Reasoning : The question requires combining sales performance from the CSV data with customer review information from the text data to determine the product with the best reviews and its sales performance.
# [Router] CSV hint  : Filter by product_id and calculate total_revenue or units_sold to determine sales performance
# [Router] Text hint : Search product page .txt files for keywords like 'review', 'rating', 'satisfaction' to determine customer review quality
#
# [Retrieving] → CSV source...
# [Retrieving] → Text source...
#
# [Generating answer...]
#
# ============================================================
# [ANSWER]
# ============================================================
# ### Analysis of Customer Reviews and Sales Performance
#
# To determine which product has the best customer reviews and how well it is selling, we need to cross-reference the sales data with the product review information.
#
# #### Top Products by Revenue
#
# According to the **Total Revenue by Category** and **Top 15 Products by Revenue** sections in the sales data, the top-selling products are:
#
# 1. Smart Watch Pro - $208,379.86
# 2. Winter Jacket Women - $138,817.28
# 3. Running Shoes Men - $117,319.62
#
# #### Product Review Analysis
#
# Looking at the product review files, we can see the average rating for each product:
#
# 1. Vitamin C Serum (BEAU001) - 4.3/5
# 2. Python Programming Guide (BOOK001) - 4.6/5
# 3. Running Shoes Men (CLTH001) - 4.4/5
# 4. Wireless Bluetooth Headphones (ELEC001) - 4.4/5
# 5. Organic Coffee Beans 1kg (FOOD001) - 4.6/5
# 6. Yoga Mat Premium (SPRT001) - 4.5/5
# 7. Air Fryer 5.5L (HOME003) - 4.6/5
# 8. Ergonomic Office Chair (OFFC001) - 4.6/5
# 9. Dog Food Premium 10kg (PETS001) - 4.5/5
# 10. Building Blocks Set 500pc (TOYS001) - 4.5/5
#
# #### Best Customer Reviews and Sales Performance
#
# Based on the average rating, the products with the best customer reviews are:
#
# 1. Python Programming Guide (BOOK001) - 4.6/5
# 2. Organic Coffee Beans 1kg (FOOD001) - 4.6/5
# 3. Air Fryer 5.5L (HOME003) - 4.6/5
# 4. Ergonomic Office Chair (OFFC001) - 4.6/5
#
# Among these products, the **Python Programming Guide (BOOK001)** has a revenue of $42,453.40, which is relatively low compared to other top-selling products. However, it has an excellent average rating of 4.6/5.
#
# The **Air Fryer 5.5L (HOME003)** has a revenue of $82,884.45 and an average rating of 4.6/5, making it a well-selling product with excellent customer reviews.
#
# Therefore, the product with the best customer reviews and relatively good sales performance is the **Air Fryer 5.5L (HOME003)**.
# [Saved Q5]
#
# ============================================================
# Question: I want a product for fitness that is highly rated and sells well in the West region. What do you recommend?
# ============================================================
#
# [Router] Route     : BOTH
# [Router] Reasoning : The question requires combining sales performance in the West region with product quality and customer reviews, which involves both numerical data and text analysis.
# [Router] CSV hint  : Filter by region='West' and category related to fitness, then aggregate by product_id and units_sold
# [Router] Text hint : Search product pages for keywords like 'fitness', 'exercise', 'sports', and look for products with high customer review ratings
#
# [Retrieving] → CSV source...
# [Retrieving] → Text source...
#
# [Generating answer...]
#
# ============================================================
# [ANSWER]
# ============================================================
# **Recommendation for a Highly Rated Fitness Product in the West Region**
#
# To find a suitable product, we'll combine insights from sales data and product reviews.
#
# **Sales Performance:**
# From the "Top Products in West Region" section, we can see that the following fitness-related products are popular in the West region:
# - Running Shoes Men (301 units sold)
# - Wireless Bluetooth Headphones (265 units sold)
# - Yoga Mat Premium is not listed in the top products for the West region, but we have its product page with reviews.
#
# **Product Quality:**
# Looking at the product reviews, the Yoga Mat Premium has an average rating of 4.5/5 from 3,112 reviews, indicating high customer satisfaction. Although it's not listed in the top products for the West region, its high rating suggests it's a quality product.
#
# **Recommendation:**
# Based on the sales data and product reviews, I recommend the **Running Shoes Men**. It has sold 301 units in the West region, making it a popular choice. However, we don't have its product page with reviews to assess its quality.
#
# If you're willing to consider a product that might not be as highly sold in the West region but has excellent reviews, the **Yoga Mat Premium** is a great option. It has an average rating of 4.5/5 from a large number of reviews, indicating high customer satisfaction.
#
# **Insufficient Context:**
# To make a more informed decision, it would be helpful to have the product page with reviews for the Running Shoes Men to assess its quality. Additionally, having more information about the customer's specific fitness needs and preferences would allow for a more tailored recommendation.
# [Saved Q6]
#
# ✅ All results saved to part2_results.txt

# %% [markdown]
# ## (Optional) Interactive Mode

# %%
# Uncomment to ask your own questions
# while True:
#     q = input("Ask a question (or exit): ").strip()
#     if q.lower() in ("exit", "quit", ""):
#         break
#     print(answer_question(q))
